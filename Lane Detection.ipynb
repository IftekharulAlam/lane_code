# %%
print("hello world")
# Out:
# hello world

# %%
import tensorflow as tf

# %%
path="C:\\Users\\IftekharulAlam\\Downloads\\driver_100_30frame\\driver_100_30frame\\05250325_0272.MP4\\00000.jpg"

# %%
loadImage = tf.keras.preprocessing.image.load_img(path)

# %%
loadImage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1640x590 at 0x18BFDA29D90>
